# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
df = pd.read_csv("../Resources/charity_data.csv")
df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
df = df.drop(columns=["EIN", "NAME"], axis=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   APPLICATION_TYPE        34299 non-null  object
#  1   AFFILIATION             34299 non-null  object
#  2   CLASSIFICATION          34299 non-null  object
#  3   USE_CASE                34299 non-null  object
#  4   ORGANIZATION            34299 non-null  object
#  5   STATUS                  34299 non-null  int64
#  6   INCOME_AMT              34299 non-null  object
#  7   SPECIAL_CONSIDERATIONS  34299 non-null  object
#  8   ASK_AMT                 34299 non-null  int64
#  9   IS_SUCCESSFUL           34299 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 2.6+ MB

# %%
# Determine the number of unique values in each column.
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
df.SPECIAL_CONSIDERATIONS.value_counts()
# Out:
# N    34272
# Y       27
# Name: SPECIAL_CONSIDERATIONS, dtype: int64

# %%
df = df.drop(columns=["SPECIAL_CONSIDERATIONS"], axis=1)

# %%
df.STATUS.value_counts()
# Out:
# 1    34294
# 0        5
# Name: STATUS, dtype: int64

# %%
df = df.drop(columns=["STATUS"], axis=1)

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
bunch = df['APPLICATION_TYPE'].value_counts()
alg_bunch = list(bunch[bunch < 600].index)
mask = df['APPLICATION_TYPE'].isin(alg_bunch)
application_types_to_replace = df.loc[mask, "APPLICATION_TYPE"] = "Other"

# Replace in dataframe
for app in application_types_to_replace:
    df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Other      804
# T8         737
# T7         725
# Name: APPLICATION_TYPE, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
clas = df['CLASSIFICATION'].value_counts()
clas_bunch = list(clas[clas > 1].index)
mask = df['APPLICATION_TYPE'].isin(clas_bunch)
df.loc[mask, "APPLICATION_TYPE"] = "Other"
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4500        1
# C6100        1
# C1580        1
# C2170        1
# C4120        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
clas = df['CLASSIFICATION'].value_counts()
clas_bunch = list(clas[clas < 1000].index)
mask = df['CLASSIFICATION'].isin(clas_bunch)
classifications_to_replace = df.loc[mask, "CLASSIFICATION"] = "Other"


# Replace in dataframe
for cls in classifications_to_replace:
    df['CLASSIFICATION'] = df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   APPLICATION_TYPE  34299 non-null  object
#  1   AFFILIATION       34299 non-null  object
#  2   CLASSIFICATION    34299 non-null  object
#  3   USE_CASE          34299 non-null  object
#  4   ORGANIZATION      34299 non-null  object
#  5   INCOME_AMT        34299 non-null  object
#  6   ASK_AMT           34299 non-null  int64
#  7   IS_SUCCESSFUL     34299 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 2.1+ MB

# %%
df = pd.get_dummies(df)
df.head()
# Out:
#    ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  APPLICATION_TYPE_T19  \
# 0     5000              1                       1                     0
# 1   108590              1                       0                     0
# 2     5000              0                       0                     0
# 3     6692              1                       0                     0
# 4   142590              1                       0                     0
#
#    APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
# 0                    0                    0                    0
# 1                    1                    0                    0
# 2                    0                    0                    1
# 3                    1                    0                    0
# 4                    1                    0                    0
#
#    APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  APPLICATION_TYPE_T8  ...  \
# ...

# %%
df["ASK_AMT"].values.reshape(-1, 1)
# Out:
# array([[    5000],
#        [  108590],
#        [    5000],
#        ...,
#        [    5000],
#        [    5000],
#        [36500179]])

# %%
scaler = StandardScaler()
df["ASK_AMT"] = scaler.fit_transform(df["ASK_AMT"].values.reshape(-1, 1))
df.head()
# Out:
#     ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  APPLICATION_TYPE_T19  \
# 0 -0.031725              1                       1                     0
# 1 -0.030536              1                       0                     0
# 2 -0.031725              0                       0                     0
# 3 -0.031706              1                       0                     0
# 4 -0.030146              1                       0                     0
#
#    APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
# 0                    0                    0                    0
# 1                    1                    0                    0
# 2                    0                    0                    1
# 3                    1                    0                    0
# 4                    1                    0                    0
#
#    APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  APPLICATION_TYPE_T8  ...  \
# ...

# %%
df.columns
# Out:
# Index(['ASK_AMT', 'IS_SUCCESSFUL', 'APPLICATION_TYPE_Other',
#        'APPLICATION_TYPE_T19', 'APPLICATION_TYPE_T3', 'APPLICATION_TYPE_T4',
#        'APPLICATION_TYPE_T5', 'APPLICATION_TYPE_T6', 'APPLICATION_TYPE_T7',
#        'APPLICATION_TYPE_T8', 'AFFILIATION_CompanySponsored',
#        'AFFILIATION_Family/Parent', 'AFFILIATION_Independent',
#        'AFFILIATION_National', 'AFFILIATION_Other', 'AFFILIATION_Regional',
#        'CLASSIFICATION_C1000', 'CLASSIFICATION_C1200', 'CLASSIFICATION_C2000',
#        'CLASSIFICATION_C2100', 'CLASSIFICATION_C3000', 'CLASSIFICATION_Other',
#        'USE_CASE_CommunityServ', 'USE_CASE_Heathcare', 'USE_CASE_Other',
#        'USE_CASE_Preservation', 'USE_CASE_ProductDev',
#        'ORGANIZATION_Association', 'ORGANIZATION_Co-operative',
#        'ORGANIZATION_Corporation', 'ORGANIZATION_Trust', 'INCOME_AMT_0',
#        'INCOME_AMT_1-9999', 'INCOME_AMT_10000-24999',
#        'INCOME_AMT_100000-499999', 'INCOME_AMT_10M-50M', 'INCOME_AMT_1M-5M',
# ...

# %%
X = df.drop(["IS_SUCCESSFUL"], axis=1).values
y = df["IS_SUCCESSFUL"].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=.25, stratify=y)

print(len(X_train) / len(X))
print(len(X_test) / len(X))
# Out:
# 0.7499927111577597
# 0.25000728884224027

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
features = len(X_train[0])
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=3, activation="relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 5)                 200
#
#  dense_1 (Dense)             (None, 3)                 18
#
#  dense_2 (Dense)             (None, 1)                 4
#
# ...
# Total params: 222
# Trainable params: 222
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Fit the model to the training data
fit_model = nn.fit(X_train_scaled, y_train, epochs=25)
# Out:
# Epoch 1/25
# 804/804 [==============================] - 1s 831us/step - loss: 0.6406 - accuracy: 0.6484
# Epoch 2/25
# 804/804 [==============================] - 1s 954us/step - loss: 0.5756 - accuracy: 0.7227
# Epoch 3/25
# 804/804 [==============================] - 1s 834us/step - loss: 0.5679 - accuracy: 0.7262
# Epoch 4/25
# 804/804 [==============================] - 1s 860us/step - loss: 0.5639 - accuracy: 0.7280
# Epoch 5/25
# 804/804 [==============================] - 1s 807us/step - loss: 0.5614 - accuracy: 0.7278
# Epoch 6/25
# 804/804 [==============================] - 1s 798us/step - loss: 0.5594 - accuracy: 0.7278
# Epoch 7/25
# 804/804 [==============================] - 1s 843us/step - loss: 0.5580 - accuracy: 0.7293
# Epoch 8/25
# 804/804 [==============================] - 1s 884us/step - loss: 0.5569 - accuracy: 0.7283
# Epoch 9/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5550 - accuracy: 0.7297
# Epoch 10/25
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5588 - accuracy: 0.7202 - 331ms/epoch - 1ms/step
# Loss: 0.5588015913963318, Accuracy: 0.7202332615852356

# %%
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=8, activation="relu", input_dim=features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=4, activation="relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_13 (Dense)            (None, 8)                 320
#
#  dense_14 (Dense)            (None, 4)                 36
#
#  dense_15 (Dense)            (None, 1)                 5
#
# ...
# Total params: 361
# Trainable params: 361
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Fit the model to the training data
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 1s 857us/step - loss: 0.6025 - accuracy: 0.6911
# Epoch 2/50
# 804/804 [==============================] - 1s 930us/step - loss: 0.5667 - accuracy: 0.7218
# Epoch 3/50
# 804/804 [==============================] - 1s 943us/step - loss: 0.5606 - accuracy: 0.7269
# Epoch 4/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5576 - accuracy: 0.7289
# Epoch 5/50
# 804/804 [==============================] - 1s 992us/step - loss: 0.5558 - accuracy: 0.7285
# Epoch 6/50
# 804/804 [==============================] - 1s 978us/step - loss: 0.5549 - accuracy: 0.7282
# Epoch 7/50
# 804/804 [==============================] - 1s 926us/step - loss: 0.5541 - accuracy: 0.7285
# Epoch 8/50
# 804/804 [==============================] - 1s 858us/step - loss: 0.5535 - accuracy: 0.7289
# Epoch 9/50
# 804/804 [==============================] - 1s 831us/step - loss: 0.5527 - accuracy: 0.7294
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5571 - accuracy: 0.7236 - 355ms/epoch - 1ms/step
# Loss: 0.5571443438529968, Accuracy: 0.7236151695251465

# %%
# Train the model
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
features = len(X_train[0])
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=9, activation="relu", input_dim=features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=5, activation="relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 9)                 360
#
#  dense_7 (Dense)             (None, 5)                 50
#
#  dense_8 (Dense)             (None, 1)                 6
#
# ...
# Total params: 416
# Trainable params: 416
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Fit the model to the training data
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 1ms/step - loss: 0.6024 - accuracy: 0.6992
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5619 - accuracy: 0.7255
# Epoch 3/100
# 804/804 [==============================] - 1s 850us/step - loss: 0.5566 - accuracy: 0.7275
# Epoch 4/100
# 804/804 [==============================] - 1s 884us/step - loss: 0.5550 - accuracy: 0.7292
# Epoch 5/100
# 804/804 [==============================] - 1s 904us/step - loss: 0.5540 - accuracy: 0.7295
# Epoch 6/100
# 804/804 [==============================] - 1s 840us/step - loss: 0.5526 - accuracy: 0.7303
# Epoch 7/100
# 804/804 [==============================] - 1s 852us/step - loss: 0.5521 - accuracy: 0.7304
# Epoch 8/100
# 804/804 [==============================] - 1s 837us/step - loss: 0.5513 - accuracy: 0.7310
# Epoch 9/100
# 804/804 [==============================] - 1s 846us/step - loss: 0.5510 - accuracy: 0.7314
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5562 - accuracy: 0.7237 - 251ms/epoch - 937us/step
# Loss: 0.5561891198158264, Accuracy: 0.7237317562103271

# %%
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=8, activation="relu", input_dim=features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=6, activation="relu"))

nn.add(tf.keras.layers.Dense(units=4, activation="relu"))
# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 8)                 320
#
#  dense_10 (Dense)            (None, 6)                 54
#
#  dense_11 (Dense)            (None, 4)                 28
#
#  dense_12 (Dense)            (None, 1)                 5
#
# ...
# Total params: 407
# Trainable params: 407
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Fit the model to the training data
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6499 - accuracy: 0.6654
# Epoch 2/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5853 - accuracy: 0.7201
# Epoch 3/50
# 804/804 [==============================] - 1s 945us/step - loss: 0.5709 - accuracy: 0.7252
# Epoch 4/50
# 804/804 [==============================] - 1s 932us/step - loss: 0.5651 - accuracy: 0.7276
# Epoch 5/50
# 804/804 [==============================] - 1s 911us/step - loss: 0.5623 - accuracy: 0.7278
# Epoch 6/50
# 804/804 [==============================] - 1s 895us/step - loss: 0.5598 - accuracy: 0.7280
# Epoch 7/50
# 804/804 [==============================] - 1s 901us/step - loss: 0.5583 - accuracy: 0.7292
# Epoch 8/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5566 - accuracy: 0.7283
# Epoch 9/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5552 - accuracy: 0.7283
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5577 - accuracy: 0.7250 - 254ms/epoch - 949us/step
# Loss: 0.5577083230018616, Accuracy: 0.7250145673751831
