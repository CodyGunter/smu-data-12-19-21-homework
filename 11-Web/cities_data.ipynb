# %%
import pandas as pd

# %%
filepath = "Instructions/Resources/assets/my_clean_weather.csv"
df = pd.read_csv(filepath)
df.head()
# Out:
#             city  latitude  longitude Country  Temperature  Humidity  \
# 0       Tasiilaq   65.6145   -37.6368      GL        -4.91      92.0
# 1          Vaini  -21.2000  -175.2000      TO        24.09     100.0
# 2        Rafaela  -31.2503   -61.4867      AR        29.99      31.0
# 3  Alice Springs  -23.7000   133.8833      AU        26.75      32.0
# 4       Sidi Ali   36.0998     0.4206      DZ        11.14      81.0
#
#    Cloud Level  Wind Speed  Air Pressure          Date
# 0        100.0        3.41         975.0  1.647458e+09
# 1        100.0        1.54        1013.0  1.647458e+09
# 2          0.0        2.24        1009.0  1.647458e+09
# 3         41.0        2.57        1011.0  1.647458e+09
# 4        100.0        2.87        1011.0  1.647458e+09

# %%
df = df.drop(['Date', 'Air Pressure'], axis=1)
df.head()
# Out:
#             city  latitude  longitude Country  Temperature  Humidity  \
# 0       Tasiilaq   65.6145   -37.6368      GL        -4.91      92.0
# 1          Vaini  -21.2000  -175.2000      TO        24.09     100.0
# 2        Rafaela  -31.2503   -61.4867      AR        29.99      31.0
# 3  Alice Springs  -23.7000   133.8833      AU        26.75      32.0
# 4       Sidi Ali   36.0998     0.4206      DZ        11.14      81.0
#
#    Cloud Level  Wind Speed
# 0        100.0        3.41
# 1        100.0        1.54
# 2          0.0        2.24
# 3         41.0        2.57
# 4        100.0        2.87

# %%
df.to_html(index=False)
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>city</th>\n      <th>latitude</th>\n      <th>longitude</th>\n      <th>Country</th>\n      <th>Temperature</th>\n      <th>Humidity</th>\n      <th>Cloud Level</th>\n      <th>Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>Tasiilaq</td>\n      <td>65.6145</td>\n      <td>-37.6368</td>\n      <td>GL</td>\n      <td>-4.91</td>\n      <td>92.0</td>\n      <td>100.0</td>\n      <td>3.41</td>\n    </tr>\n    <tr>\n      <td>Vaini</td>\n      <td>-21.2000</td>\n      <td>-175.2000</td>\n      <td>TO</td>\n      <td>24.09</td>\n      <td>100.0</td>\n      <td>100.0</td>\n      <td>1.54</td>\n    </tr>\n    <tr>\n      <td>Rafaela</td>\n      <td>-31.2503</td>\n      <td>-61.4867</td>\n      <td>AR</td>\n      <td>29.99</td>\n      <td>31.0</td>\n      <td>0.0</td>\n      <td>2.24</td>\n    </tr>\n    <tr>\n      <td>Alice Springs</td>\n      <td>-23.7000</td>\n      <td>
# ...
